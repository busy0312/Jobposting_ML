# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
url=f'https://www.indeed.com/jobs?q=Data%20Anaylst'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
results = soup.find_all('div', class_="jobsearch-SerpJobCard")

# %%
# Loop through returned results
job_postings = []
for result in results:
    
    # Retrieve the thread title
    title = result.find('h2', class_='title')
    titles = title.a.text
    des_url=title.a['href']
    print(titles)
    des= result.find('div', class_='summary').ul.li.text
    print(des)
    print(f'https://www.indeed.com{des_url}')
    
 
    
#     d = {
#         'title': titles,
#         'description': des
#     }
#     job_postings.append(d)
# Out:
# Business Anaylst
# Identifies, proposes, and implements processes for improved data reliability and efficiencies in an evolving data environment.
# https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DEz8bDvtgkkVE3yuMbqawMsWMvAYQb5qDijGly9IchlHHVnDssE4q7Y8D2y0E64mpUkiRyqsc8uZiulcnQcgFsEDfQUeCWkrbPQVZfR47hrAI7HSbwB7657ABkLDyYFCJeCt5d-vuXJj3IPynTwJffDA4LUn-AXfor8OyaQMZlTGz-ZyID6TBey9WjScbN24VHBBP_dlLKHJqabo1MgcUNUCV3bbliKznv-Uj3dTJTKq-K6nNiXYeDNGuD4WpFepnLnBrU6A7FRXv778eXYDMVhC6W4qmwgfBFN_kSpA7ZILVIibe7oHkTBAWqMqMjIqvayuihYgsr6mZR-I7SlO9Ah8eBmt6KnW7k3aIC9dgXp9m5rwIWv6CBAHQkyAdCIEn2Cm_P5eq646NwldRjy2fy5rhepuoaszmArGFGBBDe3et2akgbeqQ19hQTyi0lvJC-J5c_5mh6y3_zd_F4PrKihRDTeGzMV0l_z2nZkusz1v6nKKcCcFLF0YZRrsvXE-H5aGDH8ja-5A==&p=0&fvj=0&vjs=3
#
# Data Anaylst
# A minimum of one year of working experience in data analysis or data science.
# https://www.indeed.com/rc/clk?jk=a1f0af04b3c8fc06&fccid=6336281efb631e9c&vjs=3
#
# Data Anaylst
# Maintains the confidentiality of data.
# ...

# %%
results
# Out:
# [<div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="297196106" data-empn="536550082801537" data-jk="9d135f1ba721042d" id="pj_9d135f1ba721042d">
#  <style>
#  .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}
#  </style>
#  <div class="jobcard_logo">
#  <a href="/cmp/Keter-Environmental-Services" onmousedown="this.href = appendParamsOnce(this.href, 'tk=1edn0u57o34nt000&amp;campaignid=femp&amp;from=femp');" rel="noopener" target="_blank">
#  <img alt="Keter Environmental Services" src="https://d2q79iu7y748jz.cloudfront.net/s/_logo/2686ac68791172b83a1661f4b897c2c9"/>
#  </a>
#  </div>
#  <h2 class="title">
# ...

# %%
title.a['href']
# Out:
# '/pagead/clk?mo=r&ad=-6NYlbfkN0DEz8bDvtgkkVE3yuMbqawMsWMvAYQb5qDijGly9IchlHHVnDssE4q7Y8D2y0E64mpUkiRyqsc8uZiulcnQcgFsEDfQUeCWkrbPQVZfR47hrAI7HSbwB7657ABkLDyYFCJeCt5d-vuXJj3IPynTwJffDA4LUn-AXfor8OyaQMZlTGz-ZyID6TBey9WjScbN24VHBBP_dlLKHJqabo1MgcUNUCV3bbliKznv-Uj3dTJTKq-K6nNiXYeDNGuD4WpFepnLnBrU6A7FRXv778eXYDMVhC6W4qmwgfBFN_kSpA7ZILVIibe7oHkTBAWqMqMjIqvayuihYgsr6mZR-I7SlO9Ah8eBmt6KnW7k3aIC9dgXp9m5rwIWv6CBAHQkyAdCIEn2Cm_P5eq646NwldRjy2fy5rhepuoaszmArGFGBBDe3et2akgbeqQ19hQTyi0lvJC-J5c_5mh6y3_zd_F4PrKihRDTeGzMV0l_z2nZkusz1v6nKKcCcFLF0YZRrsvXE-H5aGDH8ja-5A==&p=0&fvj=0&vjs=3'

# %% [markdown]
# ### James testing new scrape

# %%
def scrape_indeed(job_title):
    # scraping logic here
    url=f'https://www.indeed.com/jobs?q={job_title}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('div', class_="jobsearch-SerpJobCard")
    # create list of dictionaries (job postings)
    job_postings = []
    base_url = 'https://www.indeed.com'
    for result in results:
    
        # Retrieve the thread title
        #1. grab the url
        try:
            title = result.find('h2', class_='title')
            titles = title.a.text.replace("\n", "")
            des= result.find('div', class_='summary').ul.li.text
            des_url=title.a['href']
            
            
            new_url = base_url + des_url
            #2. visit  the new page/ #3. scrape the results
            job_response = requests.get(new_url)
            job_soup = BeautifulSoup(job_response.text, 'html.parser')
            job_results = job_soup.find('div', class_='jobsearch-jobDescriptionText')            
            full_des = job_results.text
            d = {
                'title': titles,
                'description': des,
                'full description': full_des,
                'des_url':new_url
            }
            job_postings.append(d)
        except:
            pass
        
        #4. save the result

        
    # create dataframe from list of dictionaries
    table_ready = pd.DataFrame(job_postings)
    insert dataframe into db
    engine = create_engine(f'postgres://opwdphsvqznbup:2bbe72a0d9f3bc2b902cbc9f4508c7edbc7f82b034203721a34a02f884b23747@ec2-52-23-14-156.compute-1.amazonaws.com:5432/df38j5m3da0igq')
    table_ready.to_sql('Jobs', engine, if_exists='append')
    return to template
    return job_postings[2:11]
#     return table_ready
# Out:
#   File "<ipython-input-28-3c60a1c687b4>", line 42
#     insert dataframe into db
#                    ^
# SyntaxError: invalid syntax

# %%
scrape_indeed("sales")
# Out:
#                                                 title  \
# 0   Experienced Inside Sales - Senior Business Adv...
# 1                  Inbound Sales Chat Representatives
# 2   New & Used Car Sales with Benefits, Salary and...
# 3                            Fitness Sales Consultant
# 4                         Automotive Sales Consultant
# 5         Solar Sales Canvasser ($20/Hr + Commission)
# 6              Best Damn [Email-Only] Sales Associate
# 7                                Sales Representative
# 8                        Outside Sales Representative
# 9   Sales Representative - Pharmaceutical - Primar...
# 10                       Medical Sales Representative
# 11                    Internet Sales Representative I
# 12                 Remote Inside Sales Representative
# 13                   Entry Level Medical Device Sales
# 14                             Store Sales Specialist
# 15                           Outside Sales Consultant
# ...

# %%
test_url = "https://www.indeed.com/rc/clk?jk=aab618681f5d933b&fccid=6c03bc716aaab13e&vjs=3"

job_response = requests.get(test_url)
job_soup = BeautifulSoup(job_response.text, 'html.parser')
job_results = job_soup.find('div', class_= 'jobsearch-jobDescriptionText')
print(job_results.text)
# Out:
# About teambuilding™
# teambuilding™ is a leader in the online team building industry and we are a 100% remote company. We offer a variety of virtual team building activities for remote teams. The goal is to help make jobs awesome... everywhere!
# Our Mission
# We believe that workplaces are made up of kind, hardworking people that want to do their best work.
# We believe that those individuals, as part of a team, can achieve extraordinary things together.
# We believe that the work week is f***ing awesome!
# We are on a mission to inspire teams to do their best work, together.
# Our Events that you will be selling
# Are typically 90 mins of team building awesomeness
# Currently facilitated virtually using Zoom
# Are designed to be wildly entertaining, with elements of intentional team building
# Are delivered + designed by amazing creative facilitators
# Typically booked by HR manager or team leaders looking to plan a great event for their team to bond!
# ...

# %% [markdown]
# ### Craigslit scrape outline

# %%
def scrape_craigslist(job_title):
    # scraping logic here
    url=f'https://austin.craigslist.org/search/jjj?query={job_title}&lang=da'    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all("a",{"class": "result-title"}) # ideed = card, cgraislist = string \
#    print(results)
    # create list of dictionaries (job postings)
    job_postings = []
    
    for result in results:
    
#         # Retrieve the thread title
#         #1. grab the url
#         try:
            title = result.text #how to extract same thing from cl text
    
           
            new_url = result['href']
            #2. visit  the new page/ #3. scrape the results
            job_response = requests.get(new_url)
            job_soup = BeautifulSoup(job_response.text, 'html.parser')
            job_results = job_soup.find("section",{"id":"postingbody"})            
            full_des = job_results.text
            d = {
                'title': title,
                'full description': format_string(full_des)
            }
#             print(d)
#             print("----------")
            job_postings.append(d)
            except:
                pass
        
        #4. save the result

        
#     # create dataframe from list of dictionaries
    table_ready = pd.DataFrame(job_postings)
#     #insert dataframe into db
    engine = create_engine(f'postgres://chokuclmimtkyt:{postgres_password}@ec2-34-239-241-25.compute-1.amazonaws.com:5432/dd6emfhb0kd90o')
    table_ready.to_sql('scraped_cl', engine, if_exists='append')
#     return to template
    return job_postings[:10]
#     return table_ready
# Out:
#   File "<ipython-input-9-d540b0f76752>", line 32
#     except:
#          ^
# SyntaxError: invalid syntax

# %%
test_url = "https://austin.craigslist.org/csr/d/austin-sales-consultant/7161137776.html?lang=da"

job_response = requests.get(test_url)
job_soup = BeautifulSoup(job_response.text, 'html.parser')
job_results = job_soup.find("section",{"id":"postingbody"}) 
print(job_results.text)
# Out:
# QR Code Link to This Post
#
#
# Driven by the desire to provide an iconic customer experience
#
# At CarMax, we ensure customers can buy the vehicles they want in a way that suits them. That demands a special kind of sales consultant: one who takes time to build relationships with customers in order to understand their true needs. Join us, and you will help each customer purchase the right car, not the most expensive one. We’ve become the nation’s largest retailer of used cars due to our honesty and transparency, and those same traits will help you succeed too.
#
# What you will do – Essential responsibilities
#
# Use your knowledge of CarMax inventory to assist customers in finding a vehicle that meets their needs
# Guide customers every step of the way, from sale or appraisal to test drives and arranging financing applications
# Complete all relevant records and documentation to ensure smooth transactions for our customers
# Learn and succeed as part of a team
#
# ...

# %%
job_title = "sales"
url=f'https://austin.craigslist.org/search/jjj?query={job_title}&lang=da'    
response = requests.get(url)
print(response.text)
# Out:
# ﻿<!DOCTYPE html>
# <html class="no-js"><head>
#     <title>austin jobs &quot;sales&quot; - craigslist</title>
#
#     <meta name="description" content="austin jobs &quot;sales&quot; - craigslist">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#     <link rel="canonical" href="https://austin.craigslist.org/search/jjj">
#     <link rel="alternate" type="application/rss+xml" href="https://austin.craigslist.org/search/jjj?format=rss&amp;query=sales&amp;lang=da" title="RSS-feed til craigslist | austin jobs &quot;sales&quot; - craigslist">
#         <link rel="next" href="https://austin.craigslist.org/search/jjj?s=120&amp;query=sales">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9">
# ...

# %%
# url="https://austin.craigslist.org/search/jjj?query=sales&lang=da"   
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
# results = soup.find_all("a",class_= "result-title")
